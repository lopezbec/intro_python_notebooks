# %% [markdown]
# # Making Decisions with Conditions
#
# **Topics:** If-Statements, Nested If-Statements
#
#
# Complete the exercises below directly in this Google Colab notebook. Once done rename the file to *"CS110_Nested_Conditions_YourName_YourLastName.ipynb"*

# %% [markdown]
# ## Exercise 1 — Match
#
# **Instructions:** Indicate which if-statement structure best applies to each scenario.
#
# ### If-statement structures
#
# - **a.** Single If
# - **b.** If-Else
# - **c.** If-Elif-Elif-...-Else
# - **d.** Nested If-Statements
#
# ### Scenarios
#
# Edit this text cell and replace each blank with **a, b, c, or d**. (just need to double click on the text book to edit, and click *close* on the top of this windonw)
#
# 1. **_____** Prints a different welcome message depending on whether or not the user is a member
# 2. **_____** Members earn a 20% discount on their order
# 3. **_____** Determines the cost of the pizza based on the size
# 4. **_____** Determines the cost of the pizza based on the size and toppings, where cost of toppings depends on pizza size
# 5. **_____** Handle whether the user enters `'Yes'`, `'No'`, or some invalid input

# %% [markdown]
# ---
#
# ## Exercise 2 — Problem Solve
#
# In Colab, write Python code to solve the problem described below.
#
# - Write a program that takes the user’s **age** and **menu choice**, and suggests a beverage based on their choice.
# - The menu and pairing options are:
#   - **Burger (B)**, pairs with either a **chocolate milkshake** (less than 21) or a **beer** (otherwise)
#   - **Spaghetti (S)**, pairs with either a **San Pellegrino** (less than 21) or **wine** (otherwise)
#   - **Tacos (T)**, pairs with either **Jarritos soda** (less than 21) or a **margarita** (otherwise)
# - If the user enters an invalid input for any of the menu options (i.e., if the user does not enter `B`, `S`, or `T`), the program should print:
#
# ```text
# Invalid
# ```
#
# Write and test your program in the code cell below.

# %%
# Exercise 2
# Write your code below.

# %% [markdown]
# ---
#
# ## Exercise 3 — Problem Solve
#
# In Colab, write Python code to solve the problem described below.
#
# - Write a program that allows the user to **order an coffee**, and prints the total cost of the order based on the user’s selections.
# - The program should prompt the user to enter the **type**, **milk**, and **size** for their coffee.
# - The options for each of these selections and their price are listed below:
#   - **Size:** Small (`S`), Medium (`M`), or Large (`L`)
#
#     - Small costs **$2.00**
#
#     - Medium costs **$3.00**
#
#     - Large costs **$4.00**
#
#   - **Type:** Iced (`I`) or Hot (`H`)
#     - Iced coffee is always **$0.50 more**
#
#   - **Milk:** Whole (`W`), Oat (`O`), or Almond (`A`)
#     - Oat and almond milk are an additional:
#       - **$0.25** for a small
#
#       - **$0.50** for a medium
#
#       - **$0.75** for a large
#
# - If the user enters an invalid input for any of the menu options, the program should print:
#
# ```text
# Invalid
# ```
#
# Write and test your program in the code cell below.

# %%
# Exercise 3
# Write your code below.
