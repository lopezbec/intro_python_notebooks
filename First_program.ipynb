# %% [markdown]
# This is my first program ever. I am very excited about it. I am learning how to use Colab

# %% [markdown]
# This program will print the word hello followed by the name of the user
# You have to print your address
# You have to print your phone number
# You have to print your favorite actor/actress/football player

# %%
# print("My name is _______")   #remove the ____ and add your Name

# %% [markdown]
# This time I am going to work with variables (more about variables next week!)

# %%
#a = ___  #remove the ____ and your age
#b = "____"   #remove the ____ and add your Name

# %% [markdown]
# We can now create a full message using variables (how would you create the message?)

# %%
#print("My name is" __  ___  __ "and I am" __ __ __ "years old")   #fill in the blacks ___

# %% [markdown]
# We could also use "concatenation" to create a full message using variables (see next code chunk)

# %%
#print("My name is " __  ___  __" and I am " __  ___  __ " years old")   #fill in the blacks ___

# %% [markdown]
# We could even store out message into a variable!

# %%
message = "My name is " + b + " and I am " + str(a) + "years old"

print(message)

# %% [markdown]
# Update the original message such that all values are in variables:
# * Name
# * Phone number
# * Address
# * Favorite actor/actress/football player
#
#
# And display them in a sentence using both methods
